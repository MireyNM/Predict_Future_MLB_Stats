# %%
# Load necessary libraries
import pandas as pd
from pathlib import Path

# %%
# Read the data
data2015 = pd.read_csv('../static/data/Raw_Data/poptime2015.csv')
data2016 = pd.read_csv('../static/data/Raw_Data/poptime2016.csv')
data2017 = pd.read_csv('../static/data/Raw_Data/poptime2017.csv')
data2018 = pd.read_csv('../static/data/Raw_Data/poptime2018.csv')
data2019 = pd.read_csv('../static/data/Raw_Data/poptime2019.csv')
data2020 = pd.read_csv('../static/data/Raw_Data/poptime2020.csv')
data2021 = pd.read_csv('../static/data/Raw_Data/poptime2021.csv')
data2022 = pd.read_csv('../static/data/Raw_Data/poptime2022.csv')

# %%
# Checking for unnecessary columns
data2015
# Out:
#     year                catcher  player_id  team_id   age  \
# 0   2015          Chris Stewart        NaN    134.0  33.0
# 1   2015  Christian Bethancourt        NaN    144.0  23.0
# 2   2015       Martín Maldonado        NaN    158.0  28.0
# 3   2015          Austin Hedges        NaN    135.0  22.0
# 4   2015          J.T. Realmuto        NaN    146.0  24.0
# ..   ...                    ...        ...      ...   ...
# 69  2015            Brayan Peña        NaN    113.0  33.0
# 70  2015          Tyler Flowers        NaN    145.0  29.0
# 71  2015         Jordan Pacheco        NaN    109.0  29.0
# 72  2015          Chris Gimenez        NaN    140.0  32.0
# 73  2015         Kyle Schwarber        NaN    112.0  22.0
#
#     maxeff_arm_2b_3b_sba  exchange_2b_3b_sba  pop_2b_sba_count  pop_2b_sba  \
# 0                   80.0                0.61                32        1.91
# 1                   89.5                0.72                12        1.89
# ...

# %%
# Split first and last name 2015
data2015[['first_name','last_name']] = data2015['catcher'].loc[data2015['catcher'].str.split().str.len() == 2].str.split(expand=True)
data2015
# Out:
#     year                catcher  player_id  team_id   age  \
# 0   2015          Chris Stewart        NaN    134.0  33.0
# 1   2015  Christian Bethancourt        NaN    144.0  23.0
# 2   2015       Martín Maldonado        NaN    158.0  28.0
# 3   2015          Austin Hedges        NaN    135.0  22.0
# 4   2015          J.T. Realmuto        NaN    146.0  24.0
# ..   ...                    ...        ...      ...   ...
# 69  2015            Brayan Peña        NaN    113.0  33.0
# 70  2015          Tyler Flowers        NaN    145.0  29.0
# 71  2015         Jordan Pacheco        NaN    109.0  29.0
# 72  2015          Chris Gimenez        NaN    140.0  32.0
# 73  2015         Kyle Schwarber        NaN    112.0  22.0
#
#     maxeff_arm_2b_3b_sba  exchange_2b_3b_sba  pop_2b_sba_count  pop_2b_sba  \
# 0                   80.0                0.61                32        1.91
# 1                   89.5                0.72                12        1.89
# ...

# %%
# Dropping unnecessary columns in 2015 data
data2015 = data2015.drop(columns=['player_id','catcher','team_id', 'age', 'pop_2b_sba_count', 'pop_2b_sba', 'pop_2b_cs', 'pop_2b_sb', 'pop_3b_sba_count', 'pop_3b_sba', 'pop_3b_cs', 'pop_3b_sb'])
data2015
# Out:
#     year  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba first_name    last_name
# 0   2015                  80.0                0.61      Chris      Stewart
# 1   2015                  89.5                0.72  Christian  Bethancourt
# 2   2015                  88.1                0.74     Martín    Maldonado
# 3   2015                  87.3                0.76     Austin       Hedges
# 4   2015                  88.5                0.76       J.T.     Realmuto
# ..   ...                   ...                 ...        ...          ...
# 69  2015                  80.1                0.81     Brayan         Peña
# 70  2015                  77.7                0.78      Tyler      Flowers
# 71  2015                  75.7                0.75     Jordan      Pacheco
# 72  2015                  78.8                0.80      Chris      Gimenez
# 73  2015                  81.4                0.76       Kyle    Schwarber
#
# [74 rows x 5 columns]

# %%
# Split first and last name 2016
data2016[['first_name','last_name']] = data2016['catcher'].loc[data2016['catcher'].str.split().str.len() == 2].str.split(expand=True)
data2016
# Out:
#     year             catcher  player_id  team_id   age  maxeff_arm_2b_3b_sba  \
# 0   2016        Gary Sanchez        NaN    147.0  23.0                  88.4
# 1   2016       J.T. Realmuto        NaN    146.0  25.0                  87.0
# 2   2016  Welington Castillo        NaN    109.0  29.0                  83.3
# 3   2016    Martín Maldonado        NaN    158.0  29.0                  87.3
# 4   2016      Salvador Perez        NaN    118.0  26.0                  83.9
# ..   ...                 ...        ...      ...   ...                   ...
# 75  2016        Stephen Vogt        NaN    133.0  31.0                  76.3
# 76  2016   Robinson Chirinos        NaN    140.0  32.0                  80.8
# 77  2016       Austin Romine        NaN    147.0  27.0                  82.7
# 78  2016       Tyler Flowers        NaN    144.0  30.0                  76.7
# 79  2016       Bruce Maxwell        NaN    133.0  25.0                  79.0
#
# ...

# %%
# Dropping unnecessary columns in 2016 data
data2016 = data2016.drop(columns=['player_id','catcher','team_id', 'age', 'pop_2b_sba_count', 'pop_2b_sba', 'pop_2b_cs', 'pop_2b_sb', 'pop_3b_sba_count', 'pop_3b_sba', 'pop_3b_cs', 'pop_3b_sb'])
data2016
# Out:
#     year  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba first_name  last_name
# 0   2016                  88.4                0.72       Gary    Sanchez
# 1   2016                  87.0                0.70       J.T.   Realmuto
# 2   2016                  83.3                0.67  Welington   Castillo
# 3   2016                  87.3                0.70     Martín  Maldonado
# 4   2016                  83.9                0.67   Salvador      Perez
# ..   ...                   ...                 ...        ...        ...
# 75  2016                  76.3                0.71    Stephen       Vogt
# 76  2016                  80.8                0.81   Robinson   Chirinos
# 77  2016                  82.7                0.83     Austin     Romine
# 78  2016                  76.7                0.74      Tyler    Flowers
# 79  2016                  79.0                0.68      Bruce    Maxwell
#
# [80 rows x 5 columns]

# %%
# Split first and last name 2017
data2017[['first_name','last_name']] = data2017['catcher'].loc[data2017['catcher'].str.split().str.len() == 2].str.split(expand=True)
data2017
# Out:
#     year            catcher  player_id  team_id   age  maxeff_arm_2b_3b_sba  \
# 0   2017      Chris Stewart        NaN    134.0  35.0                  79.8
# 1   2017       Luis Torrens        NaN    135.0  21.0                  81.3
# 2   2017     Salvador Perez        NaN    118.0  27.0                  82.7
# 3   2017  Willson Contreras        NaN    112.0  25.0                  86.7
# 4   2017      Austin Hedges        NaN    135.0  24.0                  85.8
# ..   ...                ...        ...      ...   ...                   ...
# 67  2017        Carlos Ruiz        NaN    136.0  38.0                  79.0
# 68  2017       Brian McCann        NaN    117.0  33.0                  77.8
# 69  2017     Miguel Montero        NaN    141.0  33.0                  79.9
# 70  2017      Tyler Flowers        NaN    144.0  31.0                  74.7
# 71  2017     Brett Nicholas        NaN    140.0  28.0                  79.0
#
# ...

# %%
# Dropping unnecessary columns in 2017 data
data2017 = data2017.drop(columns=['player_id','catcher','team_id', 'age', 'pop_2b_sba_count', 'pop_2b_sba', 'pop_2b_cs', 'pop_2b_sb', 'pop_3b_sba_count', 'pop_3b_sba', 'pop_3b_cs', 'pop_3b_sb'])
data2017
# Out:
#     year  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba first_name  last_name
# 0   2017                  79.8                0.64      Chris    Stewart
# 1   2017                  81.3                0.72       Luis    Torrens
# 2   2017                  82.7                0.65   Salvador      Perez
# 3   2017                  86.7                0.73    Willson  Contreras
# 4   2017                  85.8                0.70     Austin     Hedges
# ..   ...                   ...                 ...        ...        ...
# 67  2017                  79.0                0.78     Carlos       Ruiz
# 68  2017                  77.8                0.76      Brian     McCann
# 69  2017                  79.9                0.80     Miguel    Montero
# 70  2017                  74.7                0.75      Tyler    Flowers
# 71  2017                  79.0                0.73      Brett   Nicholas
#
# [72 rows x 5 columns]

# %%
# Split first and last name 2018
data2018[['first_name','last_name']] = data2018['catcher'].loc[data2018['catcher'].str.split().str.len() == 2].str.split(expand=True)
data2018
# Out:
#     year             catcher  player_id  team_id  age  maxeff_arm_2b_3b_sba  \
# 0   2018       J.T. Realmuto        NaN      146   27                  87.8
# 1   2018        Jorge Alfaro        NaN      143   25                  90.9
# 2   2018     Kyle Higashioka        NaN      147   28                  80.5
# 3   2018  Willians Astudillo        NaN      142   26                  79.7
# 4   2018     Meibrys Viloria        NaN      118   21                  84.5
# ..   ...                 ...        ...      ...  ...                   ...
# 80  2018       Chris Gimenez        NaN      142   35                  79.4
# 81  2018     Victor Caratini        NaN      112   24                  80.7
# 82  2018        Danny Jansen        NaN      141   23                  81.9
# 83  2018      Francisco Peña        NaN      138   28                  81.3
# 84  2018       David Freitas        NaN      136   29                  79.4
#
# ...

# %%
# Dropping unnecessary columns in 2018 data
data2018 = data2018.drop(columns=['player_id','catcher','team_id', 'age', 'pop_2b_sba_count', 'pop_2b_sba', 'pop_2b_cs', 'pop_2b_sb', 'pop_3b_sba_count', 'pop_3b_sba', 'pop_3b_cs', 'pop_3b_sb'])
data2018
# Out:
#     year  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba first_name   last_name
# 0   2018                  87.8                0.69       J.T.    Realmuto
# 1   2018                  90.9                0.73      Jorge      Alfaro
# 2   2018                  80.5                0.69       Kyle  Higashioka
# 3   2018                  79.7                0.72   Willians   Astudillo
# 4   2018                  84.5                0.72    Meibrys     Viloria
# ..   ...                   ...                 ...        ...         ...
# 80  2018                  79.4                0.78      Chris     Gimenez
# 81  2018                  80.7                0.81     Victor    Caratini
# 82  2018                  81.9                0.82      Danny      Jansen
# 83  2018                  81.3                0.77  Francisco        Peña
# 84  2018                  79.4                0.78      David     Freitas
#
# [85 rows x 5 columns]

# %%
# Split first and last name 2019
data2019[['first_name','last_name']] = data2019['catcher'].loc[data2019['catcher'].str.split().str.len() == 2].str.split(expand=True)
data2019
# Out:
#     year            catcher  player_id  team_id  age  maxeff_arm_2b_3b_sba  \
# 0   2019         Tomás Nido        NaN      121   25                  80.1
# 1   2019      J.T. Realmuto        NaN      143   28                  88.4
# 2   2019        Jake Rogers        NaN      116   24                  79.2
# 3   2019  Willson Contreras        NaN      112   27                  84.7
# 4   2019     Russell Martin        NaN      119   36                  83.6
# ..   ...                ...        ...      ...  ...                   ...
# 73  2019        Jeff Mathis        NaN      140   36                  76.5
# 74  2019      Austin Barnes        NaN      119   29                  76.8
# 75  2019       Stephen Vogt        NaN      137   34                  73.4
# 76  2019      Austin Romine        NaN      147   30                  82.2
# 77  2019       Caleb Joseph        NaN      109   33                  79.3
#
# ...

# %%
# Dropping unnecessary columns in 2019 data
data2019 = data2019.drop(columns=['player_id','catcher','team_id', 'age', 'pop_2b_sba_count', 'pop_2b_sba', 'pop_2b_cs', 'pop_2b_sb', 'pop_3b_sba_count', 'pop_3b_sba', 'pop_3b_cs', 'pop_3b_sb'])
data2019
# Out:
#     year  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba first_name  last_name
# 0   2019                  80.1                0.67      Tomás       Nido
# 1   2019                  88.4                0.68       J.T.   Realmuto
# 2   2019                  79.2                0.65       Jake     Rogers
# 3   2019                  84.7                0.68    Willson  Contreras
# 4   2019                  83.6                0.75    Russell     Martin
# ..   ...                   ...                 ...        ...        ...
# 73  2019                  76.5                0.77       Jeff     Mathis
# 74  2019                  76.8                0.67     Austin     Barnes
# 75  2019                  73.4                0.70    Stephen       Vogt
# 76  2019                  82.2                0.83     Austin     Romine
# 77  2019                  79.3                0.78      Caleb     Joseph
#
# [78 rows x 5 columns]

# %%
# Split first and last name 2020
data2020[['first_name','last_name']] = data2020['catcher'].loc[data2020['catcher'].str.split().str.len() == 2].str.split(expand=True)
data2020
# Out:
#     year            catcher  player_id  team_id  age  maxeff_arm_2b_3b_sba  \
# 0   2020      J.T. Realmuto        NaN      143   29                  87.2
# 1   2020   Jacob Nottingham        NaN      158   25                  84.1
# 2   2020       Jorge Alfaro        NaN      146   27                  87.6
# 3   2020  Willson Contreras        NaN      112   28                  84.6
# 4   2020        Sean Murphy        NaN      133   25                  86.4
# 5   2020       Jason Castro        NaN      135   33                  82.4
# 6   2020     Salvador Perez        NaN      118   30                  81.0
# 7   2020       Chad Wallach        NaN      146   28                  80.0
# 8   2020      Austin Hedges        NaN      114   27                  81.3
# 9   2020        Mike Zunino        NaN      139   29                  81.1
# 10  2020       Luis Torrens        NaN      136   24                  81.4
# ...

# %%
# Dropping unnecessary columns in 2020 data
data2020 = data2020.drop(columns=['player_id','catcher','team_id', 'age', 'pop_2b_sba_count', 'pop_2b_sba', 'pop_2b_cs', 'pop_2b_sb', 'pop_3b_sba_count', 'pop_3b_sba', 'pop_3b_cs', 'pop_3b_sb'])
data2020
# Out:
#     year  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba first_name   last_name
# 0   2020                  87.2                0.69       J.T.    Realmuto
# 1   2020                  84.1                0.76      Jacob  Nottingham
# 2   2020                  87.6                0.81      Jorge      Alfaro
# 3   2020                  84.6                0.75    Willson   Contreras
# 4   2020                  86.4                0.72       Sean      Murphy
# 5   2020                  82.4                0.74      Jason      Castro
# 6   2020                  81.0                0.75   Salvador       Perez
# 7   2020                  80.0                0.70       Chad     Wallach
# 8   2020                  81.3                0.68     Austin      Hedges
# 9   2020                  81.1                0.65       Mike      Zunino
# 10  2020                  81.4                0.72       Luis     Torrens
# 11  2020                  81.0                0.72    Anthony     Bemboom
# ...

# %%
# Split first and last name 2021
data2021[['first_name','last_name']] = data2021['catcher'].loc[data2021['catcher'].str.split().str.len() == 2].str.split(expand=True)
data2021
# Out:
#     year          catcher  player_id  team_id   age  maxeff_arm_2b_3b_sba  \
# 0   2021    J.T. Realmuto        NaN    143.0  30.0                  87.8
# 1   2021    Webster Rivas        NaN    135.0  30.0                  81.1
# 2   2021  Kyle Higashioka        NaN    147.0  31.0                  83.7
# 3   2021     Danny Jansen        NaN    141.0  26.0                  81.8
# 4   2021    Yadier Molina        NaN    138.0  38.0                  83.2
# ..   ...              ...        ...      ...   ...                   ...
# 77  2021     Jose Trevino        NaN    140.0  28.0                  74.0
# 78  2021       Sandy Leon        NaN    146.0  32.0                  77.8
# 79  2021  Patrick Mazeika        NaN    121.0  27.0                  76.1
# 80  2021      Seby Zavala        NaN    145.0  27.0                  81.4
# 81  2021   Kevin Plawecki        NaN    111.0  30.0                  76.0
#
#     exchange_2b_3b_sba  pop_2b_sba_count  pop_2b_sba  pop_2b_cs  pop_2b_sb  \
# ...

# %%
# Dropping unnecessary columns in 2021 data
data2021 = data2021.drop(columns=['player_id','catcher','team_id', 'age', 'pop_2b_sba_count', 'pop_2b_sba', 'pop_2b_cs', 'pop_2b_sb', 'pop_3b_sba_count', 'pop_3b_sba', 'pop_3b_cs', 'pop_3b_sb'])
data2021
# Out:
#     year  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba first_name   last_name
# 0   2021                  87.8                0.71       J.T.    Realmuto
# 1   2021                  81.1                0.68    Webster       Rivas
# 2   2021                  83.7                0.68       Kyle  Higashioka
# 3   2021                  81.8                0.71      Danny      Jansen
# 4   2021                  83.2                0.69     Yadier      Molina
# ..   ...                   ...                 ...        ...         ...
# 77  2021                  74.0                0.71       Jose     Trevino
# 78  2021                  77.8                0.74      Sandy        Leon
# 79  2021                  76.1                0.81    Patrick     Mazeika
# 80  2021                  81.4                0.82       Seby      Zavala
# 81  2021                  76.0                0.76      Kevin    Plawecki
#
# [82 rows x 5 columns]

# %%
# Split first and last name 2022
data2022[['first_name','last_name']] = data2022['catcher'].loc[data2022['catcher'].str.split().str.len() == 2].str.split(expand=True)
data2022
# Out:
#     year           catcher  player_id  team_id  age  maxeff_arm_2b_3b_sba  \
# 0   2022       Matt Thaiss        NaN      108   27                  83.9
# 1   2022     J.T. Realmuto        NaN      143   31                  87.6
# 2   2022        Elias Díaz        NaN      115   31                  84.8
# 3   2022        Will Smith        NaN      119   27                  83.6
# 4   2022  Chuckie Robinson        NaN      113   27                  86.3
# ..   ...               ...        ...      ...  ...                   ...
# 79  2022      Austin Wynns        NaN      137   31                  78.7
# 80  2022      Tres Barrera        NaN      120   27                  76.7
# 81  2022      Mitch Garver        NaN      140   31                  81.0
# 82  2022          Sam Huff        NaN      140   24                  88.1
# 83  2022        René Pinto        NaN      139   25                  83.4
#
#     exchange_2b_3b_sba  pop_2b_sba_count  pop_2b_sba  pop_2b_cs  pop_2b_sb  \
# ...

# %%
# Dropping unnecessary columns in 2022 data
data2022 = data2022.drop(columns=['player_id','catcher','team_id', 'age', 'pop_2b_sba_count', 'pop_2b_sba', 'pop_2b_cs', 'pop_2b_sb', 'pop_3b_sba_count', 'pop_3b_sba', 'pop_3b_cs', 'pop_3b_sb'])
data2022
# Out:
#     year  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba first_name last_name
# 0   2022                  83.9                0.79       Matt    Thaiss
# 1   2022                  87.6                0.67       J.T.  Realmuto
# 2   2022                  84.8                0.72      Elias      Díaz
# 3   2022                  83.6                0.71       Will     Smith
# 4   2022                  86.3                0.73    Chuckie  Robinson
# ..   ...                   ...                 ...        ...       ...
# 79  2022                  78.7                0.76     Austin     Wynns
# 80  2022                  76.7                0.75       Tres   Barrera
# 81  2022                  81.0                0.81      Mitch    Garver
# 82  2022                  88.1                0.83        Sam      Huff
# 83  2022                  83.4                0.72       René     Pinto
#
# [84 rows x 5 columns]

# %%
# Checking data types
data2015.dtypes
# Out:
# year                      int64
# maxeff_arm_2b_3b_sba    float64
# exchange_2b_3b_sba      float64
# first_name               object
# last_name                object
# dtype: object

# %%
# Distance variables in meters
distance_second = 38.71
distance_third = 27.432

# %%
# Calculating time for Second and Third base for 2015 into meters per milisecond
data2015['time_second_base'] = (distance_second/data2015['maxeff_arm_2b_3b_sba']*0.44704)*1000
data2015['time_third_base'] = (distance_third/data2015['maxeff_arm_2b_3b_sba']*0.44704)*1000
data2015
# Out:
#     year  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba first_name    last_name  \
# 0   2015                  80.0                0.61      Chris      Stewart
# 1   2015                  89.5                0.72  Christian  Bethancourt
# 2   2015                  88.1                0.74     Martín    Maldonado
# 3   2015                  87.3                0.76     Austin       Hedges
# 4   2015                  88.5                0.76       J.T.     Realmuto
# ..   ...                   ...                 ...        ...          ...
# 69  2015                  80.1                0.81     Brayan         Peña
# 70  2015                  77.7                0.78      Tyler      Flowers
# 71  2015                  75.7                0.75     Jordan      Pacheco
# 72  2015                  78.8                0.80      Chris      Gimenez
# 73  2015                  81.4                0.76       Kyle    Schwarber
#
#     time_second_base  time_third_base
# ...

# %%
# Calculating time for Second and Third base for 2016 into meters per milisecond
data2016['time_second_base'] = (distance_second/data2016['maxeff_arm_2b_3b_sba']*0.44704)*1000
data2016['time_third_base'] = (distance_third/data2016['maxeff_arm_2b_3b_sba']*0.44704)*1000
data2016
# Out:
#     year  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba first_name  last_name  \
# 0   2016                  88.4                0.72       Gary    Sanchez
# 1   2016                  87.0                0.70       J.T.   Realmuto
# 2   2016                  83.3                0.67  Welington   Castillo
# 3   2016                  87.3                0.70     Martín  Maldonado
# 4   2016                  83.9                0.67   Salvador      Perez
# ..   ...                   ...                 ...        ...        ...
# 75  2016                  76.3                0.71    Stephen       Vogt
# 76  2016                  80.8                0.81   Robinson   Chirinos
# 77  2016                  82.7                0.83     Austin     Romine
# 78  2016                  76.7                0.74      Tyler    Flowers
# 79  2016                  79.0                0.68      Bruce    Maxwell
#
#     time_second_base  time_third_base
# 0         195.756995       138.723996
# ...

# %%
# Calculating time for Second and Third base for 2017 into meters per milisecond
data2017['time_second_base'] = (distance_second/data2017['maxeff_arm_2b_3b_sba']*0.44704)*1000
data2017['time_third_base'] = (distance_third/data2017['maxeff_arm_2b_3b_sba']*0.44704)*1000
data2017
# Out:
#     year  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba first_name  last_name  \
# 0   2017                  79.8                0.64      Chris    Stewart
# 1   2017                  81.3                0.72       Luis    Torrens
# 2   2017                  82.7                0.65   Salvador      Perez
# 3   2017                  86.7                0.73    Willson  Contreras
# 4   2017                  85.8                0.70     Austin     Hedges
# ..   ...                   ...                 ...        ...        ...
# 67  2017                  79.0                0.78     Carlos       Ruiz
# 68  2017                  77.8                0.76      Brian     McCann
# 69  2017                  79.9                0.80     Miguel    Montero
# 70  2017                  74.7                0.75      Tyler    Flowers
# 71  2017                  79.0                0.73      Brett   Nicholas
#
#     time_second_base  time_third_base
# 0         216.853614       153.674202
# ...

# %%
# Calculating time for Second and Third base for 2018 into meters per milisecond
data2018['time_second_base'] = (distance_second/data2018['maxeff_arm_2b_3b_sba']*0.44704)*1000
data2018['time_third_base'] = (distance_third/data2018['maxeff_arm_2b_3b_sba']*0.44704)*1000
data2018
# Out:
#     year  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba first_name   last_name  \
# 0   2018                  87.8                0.69       J.T.    Realmuto
# 1   2018                  90.9                0.73      Jorge      Alfaro
# 2   2018                  80.5                0.69       Kyle  Higashioka
# 3   2018                  79.7                0.72   Willians   Astudillo
# 4   2018                  84.5                0.72    Meibrys     Viloria
# ..   ...                   ...                 ...        ...         ...
# 80  2018                  79.4                0.78      Chris     Gimenez
# 81  2018                  80.7                0.81     Victor    Caratini
# 82  2018                  81.9                0.82      Danny      Jansen
# 83  2018                  81.3                0.77  Francisco        Peña
# 84  2018                  79.4                0.78      David     Freitas
#
#     time_second_base  time_third_base
# 0         197.094743       139.671996
# ...

# %%
# Calculating time for Second and Third base for 2019 into meters per milisecond
data2019['time_second_base'] = (distance_second/data2019['maxeff_arm_2b_3b_sba']*0.44704)*1000
data2019['time_third_base'] = (distance_third/data2019['maxeff_arm_2b_3b_sba']*0.44704)*1000
data2019
# Out:
#     year  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba first_name  last_name  \
# 0   2019                  80.1                0.67      Tomás       Nido
# 1   2019                  88.4                0.68       J.T.   Realmuto
# 2   2019                  79.2                0.65       Jake     Rogers
# 3   2019                  84.7                0.68    Willson  Contreras
# 4   2019                  83.6                0.75    Russell     Martin
# ..   ...                   ...                 ...        ...        ...
# 73  2019                  76.5                0.77       Jeff     Mathis
# 74  2019                  76.8                0.67     Austin     Barnes
# 75  2019                  73.4                0.70    Stephen       Vogt
# 76  2019                  82.2                0.83     Austin     Romine
# 77  2019                  79.3                0.78      Caleb     Joseph
#
#     time_second_base  time_third_base
# 0         216.041428       153.098643
# ...

# %%
# Calculating time for Second and Third base for 2020 into meters per milisecond
data2020['time_second_base'] = (distance_second/data2020['maxeff_arm_2b_3b_sba']*0.44704)*1000
data2020['time_third_base'] = (distance_third/data2020['maxeff_arm_2b_3b_sba']*0.44704)*1000
data2020
# Out:
#     year  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba first_name   last_name  \
# 0   2020                  87.2                0.69       J.T.    Realmuto
# 1   2020                  84.1                0.76      Jacob  Nottingham
# 2   2020                  87.6                0.81      Jorge      Alfaro
# 3   2020                  84.6                0.75    Willson   Contreras
# 4   2020                  86.4                0.72       Sean      Murphy
# 5   2020                  82.4                0.74      Jason      Castro
# 6   2020                  81.0                0.75   Salvador       Perez
# 7   2020                  80.0                0.70       Chad     Wallach
# 8   2020                  81.3                0.68     Austin      Hedges
# 9   2020                  81.1                0.65       Mike      Zunino
# 10  2020                  81.4                0.72       Luis     Torrens
# 11  2020                  81.0                0.72    Anthony     Bemboom
# ...

# %%
# Calculating time for Second and Third base for 2021 into meters per milisecond
data2021['time_second_base'] = (distance_second/data2021['maxeff_arm_2b_3b_sba']*0.44704)*1000
data2021['time_third_base'] = (distance_third/data2021['maxeff_arm_2b_3b_sba']*0.44704)*1000
data2021
# Out:
#     year  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba first_name   last_name  \
# 0   2021                  87.8                0.71       J.T.    Realmuto
# 1   2021                  81.1                0.68    Webster       Rivas
# 2   2021                  83.7                0.68       Kyle  Higashioka
# 3   2021                  81.8                0.71      Danny      Jansen
# 4   2021                  83.2                0.69     Yadier      Molina
# ..   ...                   ...                 ...        ...         ...
# 77  2021                  74.0                0.71       Jose     Trevino
# 78  2021                  77.8                0.74      Sandy        Leon
# 79  2021                  76.1                0.81    Patrick     Mazeika
# 80  2021                  81.4                0.82       Seby      Zavala
# 81  2021                  76.0                0.76      Kevin    Plawecki
#
#     time_second_base  time_third_base
# 0         197.094743       139.671996
# ...

# %%
# Calculating time for Second and Third base for 2022 into meters per milisecond
data2022['time_second_base'] = (distance_second/data2022['maxeff_arm_2b_3b_sba']*0.44704)*1000
data2022['time_third_base'] = (distance_third/data2022['maxeff_arm_2b_3b_sba']*0.44704)*1000
data2022
# Out:
#     year  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba first_name last_name  \
# 0   2022                  83.9                0.79       Matt    Thaiss
# 1   2022                  87.6                0.67       J.T.  Realmuto
# 2   2022                  84.8                0.72      Elias      Díaz
# 3   2022                  83.6                0.71       Will     Smith
# 4   2022                  86.3                0.73    Chuckie  Robinson
# ..   ...                   ...                 ...        ...       ...
# 79  2022                  78.7                0.76     Austin     Wynns
# 80  2022                  76.7                0.75       Tres   Barrera
# 81  2022                  81.0                0.81      Mitch    Garver
# 82  2022                  88.1                0.83        Sam      Huff
# 83  2022                  83.4                0.72       René     Pinto
#
#     time_second_base  time_third_base
# 0         206.256477       146.164497
# ...

# %%
# Checking for null values
data2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  74 non-null     int64
#  1   maxeff_arm_2b_3b_sba  74 non-null     float64
#  2   exchange_2b_3b_sba    74 non-null     float64
#  3   first_name            72 non-null     object
#  4   last_name             72 non-null     object
#  5   time_second_base      74 non-null     float64
#  6   time_third_base       74 non-null     float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 4.2+ KB

# %%
# Dropping null catchers in 2015
data2015 = data2015.dropna(subset=['first_name'])

# %%
# Checking for null values
data2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  80 non-null     int64
#  1   maxeff_arm_2b_3b_sba  80 non-null     float64
#  2   exchange_2b_3b_sba    80 non-null     float64
#  3   first_name            78 non-null     object
#  4   last_name             78 non-null     object
#  5   time_second_base      80 non-null     float64
#  6   time_third_base       80 non-null     float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 4.5+ KB

# %%
# Dropping null catchers in 2016
data2016 = data2016.dropna(subset=['first_name'])

# %%
# Checking for null values
data2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  72 non-null     int64
#  1   maxeff_arm_2b_3b_sba  72 non-null     float64
#  2   exchange_2b_3b_sba    72 non-null     float64
#  3   first_name            72 non-null     object
#  4   last_name             72 non-null     object
#  5   time_second_base      72 non-null     float64
#  6   time_third_base       72 non-null     float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 4.1+ KB

# %%
# Checking for null values
data2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  85 non-null     int64
#  1   maxeff_arm_2b_3b_sba  85 non-null     float64
#  2   exchange_2b_3b_sba    85 non-null     float64
#  3   first_name            84 non-null     object
#  4   last_name             84 non-null     object
#  5   time_second_base      85 non-null     float64
#  6   time_third_base       85 non-null     float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 4.8+ KB

# %%
# Dropping null catchers in 2018
data2018 = data2018.dropna(subset=['first_name'])

# %%
# Checking for null values
data2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  78 non-null     int64
#  1   maxeff_arm_2b_3b_sba  78 non-null     float64
#  2   exchange_2b_3b_sba    78 non-null     float64
#  3   first_name            78 non-null     object
#  4   last_name             78 non-null     object
#  5   time_second_base      78 non-null     float64
#  6   time_third_base       78 non-null     float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 4.4+ KB

# %%
# Checking for null values
data2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  53 non-null     int64
#  1   maxeff_arm_2b_3b_sba  53 non-null     float64
#  2   exchange_2b_3b_sba    53 non-null     float64
#  3   first_name            52 non-null     object
#  4   last_name             52 non-null     object
#  5   time_second_base      53 non-null     float64
#  6   time_third_base       53 non-null     float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 3.0+ KB

# %%
# Dropping null catchers in 2020
data2020 = data2020.dropna(subset=['first_name'])

# %%
# Checking for null values
data2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  82 non-null     int64
#  1   maxeff_arm_2b_3b_sba  82 non-null     float64
#  2   exchange_2b_3b_sba    82 non-null     float64
#  3   first_name            81 non-null     object
#  4   last_name             81 non-null     object
#  5   time_second_base      82 non-null     float64
#  6   time_third_base       82 non-null     float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 4.6+ KB

# %%
# Dropping null catchers in 2021
data2021 = data2021.dropna(subset=['first_name'])

# %%
# Checking for null values
data2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  84 non-null     int64
#  1   maxeff_arm_2b_3b_sba  84 non-null     float64
#  2   exchange_2b_3b_sba    84 non-null     float64
#  3   first_name            84 non-null     object
#  4   last_name             84 non-null     object
#  5   time_second_base      84 non-null     float64
#  6   time_third_base       84 non-null     float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 4.7+ KB

# %%
# Merging tables into the column year
frames = [data2022, data2021, data2020, data2019, data2018, data2017, data2016, data2015]

result = pd.concat(frames)

# %%
# Final table cleaned
result
# Out:
#     year  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba first_name  last_name  \
# 0   2022                  83.9                0.79       Matt     Thaiss
# 1   2022                  87.6                0.67       J.T.   Realmuto
# 2   2022                  84.8                0.72      Elias       Díaz
# 3   2022                  83.6                0.71       Will      Smith
# 4   2022                  86.3                0.73    Chuckie   Robinson
# ..   ...                   ...                 ...        ...        ...
# 69  2015                  80.1                0.81     Brayan       Peña
# 70  2015                  77.7                0.78      Tyler    Flowers
# 71  2015                  75.7                0.75     Jordan    Pacheco
# 72  2015                  78.8                0.80      Chris    Gimenez
# 73  2015                  81.4                0.76       Kyle  Schwarber
#
#     time_second_base  time_third_base
# 0         206.256477       146.164497
# ...

# %%
# export DataFrame to csv
filepath = Path('../Data/Clean_Data/catcher_data_clean.csv')
result.to_csv(filepath, index=False)
