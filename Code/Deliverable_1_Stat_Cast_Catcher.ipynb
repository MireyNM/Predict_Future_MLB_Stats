# %%
# Load necessary libraries
# %matplotlib inline
import csv
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

# %%
data2015 = pd.read_csv('../Data/poptime2015.csv')
data2016 = pd.read_csv('../Data/poptime2016.csv')
data2017 = pd.read_csv('../Data/poptime2017.csv')
data2018 = pd.read_csv('../Data/poptime2018.csv')
data2019 = pd.read_csv('../Data/poptime2019.csv')
data2020 = pd.read_csv('../Data/poptime2020.csv')
data2021 = pd.read_csv('../Data/poptime2021.csv')
data2022 = pd.read_csv('../Data/poptime2022.csv')

# %%
# Checking for unnecessary columns
data2015
# Out:
#     year                catcher  player_id  team_id   age  \
# 0   2015          Chris Stewart        NaN    134.0  33.0
# 1   2015  Christian Bethancourt        NaN    144.0  23.0
# 2   2015       Martín Maldonado        NaN    158.0  28.0
# 3   2015          Austin Hedges        NaN    135.0  22.0
# 4   2015          J.T. Realmuto        NaN    146.0  24.0
# ..   ...                    ...        ...      ...   ...
# 69  2015            Brayan Peña        NaN    113.0  33.0
# 70  2015          Tyler Flowers        NaN    145.0  29.0
# 71  2015         Jordan Pacheco        NaN    109.0  29.0
# 72  2015          Chris Gimenez        NaN    140.0  32.0
# 73  2015         Kyle Schwarber        NaN    112.0  22.0
#
#     maxeff_arm_2b_3b_sba  exchange_2b_3b_sba  pop_2b_sba_count  pop_2b_sba  \
# 0                   80.0                0.61                32        1.91
# 1                   89.5                0.72                12        1.89
# ...

# %%
# Dropping unnecessary columns in 2015 data
data2015 = data2015.drop(columns=['player_id','team_id', 'age', 'pop_2b_sba_count', 'pop_2b_sba', 'pop_2b_cs', 'pop_2b_sb', 'pop_3b_sba_count', 'pop_3b_sba', 'pop_3b_cs', 'pop_3b_sb'])
data2015
# Out:
#     year                catcher  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba
# 0   2015          Chris Stewart                  80.0                0.61
# 1   2015  Christian Bethancourt                  89.5                0.72
# 2   2015       Martín Maldonado                  88.1                0.74
# 3   2015          Austin Hedges                  87.3                0.76
# 4   2015          J.T. Realmuto                  88.5                0.76
# ..   ...                    ...                   ...                 ...
# 69  2015            Brayan Peña                  80.1                0.81
# 70  2015          Tyler Flowers                  77.7                0.78
# 71  2015         Jordan Pacheco                  75.7                0.75
# 72  2015          Chris Gimenez                  78.8                0.80
# 73  2015         Kyle Schwarber                  81.4                0.76
#
# [74 rows x 4 columns]

# %%
# Dropping unnecessary columns in 2016 data
data2016 = data2016.drop(columns=['player_id','team_id', 'age', 'pop_2b_sba_count', 'pop_2b_sba', 'pop_2b_cs', 'pop_2b_sb', 'pop_3b_sba_count', 'pop_3b_sba', 'pop_3b_cs', 'pop_3b_sb'])
data2016
# Out:
#     year             catcher  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba
# 0   2016        Gary Sanchez                  88.4                0.72
# 1   2016       J.T. Realmuto                  87.0                0.70
# 2   2016  Welington Castillo                  83.3                0.67
# 3   2016    Martín Maldonado                  87.3                0.70
# 4   2016      Salvador Perez                  83.9                0.67
# ..   ...                 ...                   ...                 ...
# 75  2016        Stephen Vogt                  76.3                0.71
# 76  2016   Robinson Chirinos                  80.8                0.81
# 77  2016       Austin Romine                  82.7                0.83
# 78  2016       Tyler Flowers                  76.7                0.74
# 79  2016       Bruce Maxwell                  79.0                0.68
#
# [80 rows x 4 columns]

# %%
# Dropping unnecessary columns in 2017 data
data2017 = data2017.drop(columns=['player_id','team_id', 'age', 'pop_2b_sba_count', 'pop_2b_sba', 'pop_2b_cs', 'pop_2b_sb', 'pop_3b_sba_count', 'pop_3b_sba', 'pop_3b_cs', 'pop_3b_sb'])
data2017
# Out:
#     year            catcher  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba
# 0   2017      Chris Stewart                  79.8                0.64
# 1   2017       Luis Torrens                  81.3                0.72
# 2   2017     Salvador Perez                  82.7                0.65
# 3   2017  Willson Contreras                  86.7                0.73
# 4   2017      Austin Hedges                  85.8                0.70
# ..   ...                ...                   ...                 ...
# 67  2017        Carlos Ruiz                  79.0                0.78
# 68  2017       Brian McCann                  77.8                0.76
# 69  2017     Miguel Montero                  79.9                0.80
# 70  2017      Tyler Flowers                  74.7                0.75
# 71  2017     Brett Nicholas                  79.0                0.73
#
# [72 rows x 4 columns]

# %%
# Dropping unnecessary columns in 2018 data
data2018 = data2018.drop(columns=['player_id','team_id', 'age', 'pop_2b_sba_count', 'pop_2b_sba', 'pop_2b_cs', 'pop_2b_sb', 'pop_3b_sba_count', 'pop_3b_sba', 'pop_3b_cs', 'pop_3b_sb'])
data2018
# Out:
#     year             catcher  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba
# 0   2018       J.T. Realmuto                  87.8                0.69
# 1   2018        Jorge Alfaro                  90.9                0.73
# 2   2018     Kyle Higashioka                  80.5                0.69
# 3   2018  Willians Astudillo                  79.7                0.72
# 4   2018     Meibrys Viloria                  84.5                0.72
# ..   ...                 ...                   ...                 ...
# 80  2018       Chris Gimenez                  79.4                0.78
# 81  2018     Victor Caratini                  80.7                0.81
# 82  2018        Danny Jansen                  81.9                0.82
# 83  2018      Francisco Peña                  81.3                0.77
# 84  2018       David Freitas                  79.4                0.78
#
# [85 rows x 4 columns]

# %%
# Dropping unnecessary columns in 2019 data
data2019 = data2019.drop(columns=['player_id','team_id', 'age', 'pop_2b_sba_count', 'pop_2b_sba', 'pop_2b_cs', 'pop_2b_sb', 'pop_3b_sba_count', 'pop_3b_sba', 'pop_3b_cs', 'pop_3b_sb'])
data2019
# Out:
#     year            catcher  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba
# 0   2019         Tomás Nido                  80.1                0.67
# 1   2019      J.T. Realmuto                  88.4                0.68
# 2   2019        Jake Rogers                  79.2                0.65
# 3   2019  Willson Contreras                  84.7                0.68
# 4   2019     Russell Martin                  83.6                0.75
# ..   ...                ...                   ...                 ...
# 73  2019        Jeff Mathis                  76.5                0.77
# 74  2019      Austin Barnes                  76.8                0.67
# 75  2019       Stephen Vogt                  73.4                0.70
# 76  2019      Austin Romine                  82.2                0.83
# 77  2019       Caleb Joseph                  79.3                0.78
#
# [78 rows x 4 columns]

# %%
# Dropping unnecessary columns in 2020 data
data2020 = data2020.drop(columns=['player_id','team_id', 'age', 'pop_2b_sba_count', 'pop_2b_sba', 'pop_2b_cs', 'pop_2b_sb', 'pop_3b_sba_count', 'pop_3b_sba', 'pop_3b_cs', 'pop_3b_sb'])
data2020
# Out:
#     year            catcher  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba
# 0   2020      J.T. Realmuto                  87.2                0.69
# 1   2020   Jacob Nottingham                  84.1                0.76
# 2   2020       Jorge Alfaro                  87.6                0.81
# 3   2020  Willson Contreras                  84.6                0.75
# 4   2020        Sean Murphy                  86.4                0.72
# 5   2020       Jason Castro                  82.4                0.74
# 6   2020     Salvador Perez                  81.0                0.75
# 7   2020       Chad Wallach                  80.0                0.70
# 8   2020      Austin Hedges                  81.3                0.68
# 9   2020        Mike Zunino                  81.1                0.65
# 10  2020       Luis Torrens                  81.4                0.72
# 11  2020    Anthony Bemboom                  81.0                0.72
# ...

# %%
# Dropping unnecessary columns in 2021 data
data2021 = data2021.drop(columns=['player_id','team_id', 'age', 'pop_2b_sba_count', 'pop_2b_sba', 'pop_2b_cs', 'pop_2b_sb', 'pop_3b_sba_count', 'pop_3b_sba', 'pop_3b_cs', 'pop_3b_sb'])
data2021
# Out:
#     year          catcher  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba
# 0   2021    J.T. Realmuto                  87.8                0.71
# 1   2021    Webster Rivas                  81.1                0.68
# 2   2021  Kyle Higashioka                  83.7                0.68
# 3   2021     Danny Jansen                  81.8                0.71
# 4   2021    Yadier Molina                  83.2                0.69
# ..   ...              ...                   ...                 ...
# 77  2021     Jose Trevino                  74.0                0.71
# 78  2021       Sandy Leon                  77.8                0.74
# 79  2021  Patrick Mazeika                  76.1                0.81
# 80  2021      Seby Zavala                  81.4                0.82
# 81  2021   Kevin Plawecki                  76.0                0.76
#
# [82 rows x 4 columns]

# %%
# Dropping unnecessary columns in 2022 data
data2022 = data2022.drop(columns=['player_id','team_id', 'age', 'pop_2b_sba_count', 'pop_2b_sba', 'pop_2b_cs', 'pop_2b_sb', 'pop_3b_sba_count', 'pop_3b_sba', 'pop_3b_cs', 'pop_3b_sb'])
data2022
# Out:
#     year           catcher  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba
# 0   2022       Matt Thaiss                  83.9                0.79
# 1   2022     J.T. Realmuto                  87.6                0.67
# 2   2022        Elias Díaz                  84.8                0.72
# 3   2022        Will Smith                  83.6                0.71
# 4   2022  Chuckie Robinson                  86.3                0.73
# ..   ...               ...                   ...                 ...
# 79  2022      Austin Wynns                  78.7                0.76
# 80  2022      Tres Barrera                  76.7                0.75
# 81  2022      Mitch Garver                  81.0                0.81
# 82  2022          Sam Huff                  88.1                0.83
# 83  2022        René Pinto                  83.4                0.72
#
# [84 rows x 4 columns]

# %%
# Checking data types
data2015.dtypes
# Out:
# year                      int64
# catcher                  object
# maxeff_arm_2b_3b_sba    float64
# exchange_2b_3b_sba      float64
# dtype: object

# %%
# Distance variables
distance_second = 38.71
distance_third = 27.432

# %%
# Calculating time for Second and Third base for 2015
data2015['time_second_base'] = (distance_second/data2015['maxeff_arm_2b_3b_sba']*0.44704)*10
data2015['time_third_base'] = (distance_third/data2015['maxeff_arm_2b_3b_sba']*0.44704)*10
data2015
# Out:
#     year                catcher  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba  \
# 0   2015          Chris Stewart                  80.0                0.61
# 1   2015  Christian Bethancourt                  89.5                0.72
# 2   2015       Martín Maldonado                  88.1                0.74
# 3   2015          Austin Hedges                  87.3                0.76
# 4   2015          J.T. Realmuto                  88.5                0.76
# ..   ...                    ...                   ...                 ...
# 69  2015            Brayan Peña                  80.1                0.81
# 70  2015          Tyler Flowers                  77.7                0.78
# 71  2015         Jordan Pacheco                  75.7                0.75
# 72  2015          Chris Gimenez                  78.8                0.80
# 73  2015         Kyle Schwarber                  81.4                0.76
#
#     time_second_base  time_third_base
# 0           2.163115         1.532900
# ...

# %%
# Calculating time for Second and Third base for 2016
data2016['time_second_base'] = (distance_second/data2016['maxeff_arm_2b_3b_sba']*0.44704)*10
data2016['time_third_base'] = (distance_third/data2016['maxeff_arm_2b_3b_sba']*0.44704)*10
data2016
# Out:
#     year             catcher  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba  \
# 0   2016        Gary Sanchez                  88.4                0.72
# 1   2016       J.T. Realmuto                  87.0                0.70
# 2   2016  Welington Castillo                  83.3                0.67
# 3   2016    Martín Maldonado                  87.3                0.70
# 4   2016      Salvador Perez                  83.9                0.67
# ..   ...                 ...                   ...                 ...
# 75  2016        Stephen Vogt                  76.3                0.71
# 76  2016   Robinson Chirinos                  80.8                0.81
# 77  2016       Austin Romine                  82.7                0.83
# 78  2016       Tyler Flowers                  76.7                0.74
# 79  2016       Bruce Maxwell                  79.0                0.68
#
#     time_second_base  time_third_base
# 0           1.957570         1.387240
# ...

# %%
# Calculating time for Second and Third base for 2017
data2017['time_second_base'] = (distance_second/data2017['maxeff_arm_2b_3b_sba']*0.44704)*10
data2017['time_third_base'] = (distance_third/data2017['maxeff_arm_2b_3b_sba']*0.44704)*10
data2017
# Out:
#     year            catcher  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba  \
# 0   2017      Chris Stewart                  79.8                0.64
# 1   2017       Luis Torrens                  81.3                0.72
# 2   2017     Salvador Perez                  82.7                0.65
# 3   2017  Willson Contreras                  86.7                0.73
# 4   2017      Austin Hedges                  85.8                0.70
# ..   ...                ...                   ...                 ...
# 67  2017        Carlos Ruiz                  79.0                0.78
# 68  2017       Brian McCann                  77.8                0.76
# 69  2017     Miguel Montero                  79.9                0.80
# 70  2017      Tyler Flowers                  74.7                0.75
# 71  2017     Brett Nicholas                  79.0                0.73
#
#     time_second_base  time_third_base
# 0           2.168536         1.536742
# 1           2.128526         1.508389
# ...

# %%
# Calculating time for Second and Third base for 2018
data2018['time_second_base'] = (distance_second/data2018['maxeff_arm_2b_3b_sba']*0.44704)*10
data2018['time_third_base'] = (distance_third/data2018['maxeff_arm_2b_3b_sba']*0.44704)*10
data2018
# Out:
#     year             catcher  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba  \
# 0   2018       J.T. Realmuto                  87.8                0.69
# 1   2018        Jorge Alfaro                  90.9                0.73
# 2   2018     Kyle Higashioka                  80.5                0.69
# 3   2018  Willians Astudillo                  79.7                0.72
# 4   2018     Meibrys Viloria                  84.5                0.72
# ..   ...                 ...                   ...                 ...
# 80  2018       Chris Gimenez                  79.4                0.78
# 81  2018     Victor Caratini                  80.7                0.81
# 82  2018        Danny Jansen                  81.9                0.82
# 83  2018      Francisco Peña                  81.3                0.77
# 84  2018       David Freitas                  79.4                0.78
#
#     time_second_base  time_third_base
# 0           1.970947         1.396720
# ...

# %%
# Calculating time for Second and Third base for 2019
data2019['time_second_base'] = (distance_second/data2019['maxeff_arm_2b_3b_sba']*0.44704)*10
data2019['time_third_base'] = (distance_third/data2019['maxeff_arm_2b_3b_sba']*0.44704)*10
data2019
# Out:
#     year            catcher  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba  \
# 0   2019         Tomás Nido                  80.1                0.67
# 1   2019      J.T. Realmuto                  88.4                0.68
# 2   2019        Jake Rogers                  79.2                0.65
# 3   2019  Willson Contreras                  84.7                0.68
# 4   2019     Russell Martin                  83.6                0.75
# ..   ...                ...                   ...                 ...
# 73  2019        Jeff Mathis                  76.5                0.77
# 74  2019      Austin Barnes                  76.8                0.67
# 75  2019       Stephen Vogt                  73.4                0.70
# 76  2019      Austin Romine                  82.2                0.83
# 77  2019       Caleb Joseph                  79.3                0.78
#
#     time_second_base  time_third_base
# 0           2.160414         1.530986
# 1           1.957570         1.387240
# ...

# %%
# Calculating time for Second and Third base for 2020
data2020['time_second_base'] = (distance_second/data2020['maxeff_arm_2b_3b_sba']*0.44704)*10
data2020['time_third_base'] = (distance_third/data2020['maxeff_arm_2b_3b_sba']*0.44704)*10
data2020
# Out:
#     year            catcher  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba  \
# 0   2020      J.T. Realmuto                  87.2                0.69
# 1   2020   Jacob Nottingham                  84.1                0.76
# 2   2020       Jorge Alfaro                  87.6                0.81
# 3   2020  Willson Contreras                  84.6                0.75
# 4   2020        Sean Murphy                  86.4                0.72
# 5   2020       Jason Castro                  82.4                0.74
# 6   2020     Salvador Perez                  81.0                0.75
# 7   2020       Chad Wallach                  80.0                0.70
# 8   2020      Austin Hedges                  81.3                0.68
# 9   2020        Mike Zunino                  81.1                0.65
# 10  2020       Luis Torrens                  81.4                0.72
# 11  2020    Anthony Bemboom                  81.0                0.72
# ...

# %%
# Calculating time for Second and Third base for 2021
data2021['time_second_base'] = (distance_second/data2021['maxeff_arm_2b_3b_sba']*0.44704)*10
data2021['time_third_base'] = (distance_third/data2021['maxeff_arm_2b_3b_sba']*0.44704)*10
data2021
# Out:
# /var/folders/hy/4q0zsdgd3tvg2clt2qgl_5yr0000gn/T/ipykernel_4461/3087251355.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2021['time_second_base'] = (distance_second/data2021['maxeff_arm_2b_3b_sba']*0.44704)*10
# /var/folders/hy/4q0zsdgd3tvg2clt2qgl_5yr0000gn/T/ipykernel_4461/3087251355.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2021['time_third_base'] = (distance_third/data2021['maxeff_arm_2b_3b_sba']*0.44704)*10
# ...

# %%
# Calculating time for Second and Third base for 2022
data2022['time_second_base'] = (distance_second/data2022['maxeff_arm_2b_3b_sba']*0.44704)*10
data2022['time_third_base'] = (distance_third/data2022['maxeff_arm_2b_3b_sba']*0.44704)*10
data2022
# Out:
#     year           catcher  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba  \
# 0   2022       Matt Thaiss                  83.9                0.79
# 1   2022     J.T. Realmuto                  87.6                0.67
# 2   2022        Elias Díaz                  84.8                0.72
# 3   2022        Will Smith                  83.6                0.71
# 4   2022  Chuckie Robinson                  86.3                0.73
# ..   ...               ...                   ...                 ...
# 79  2022      Austin Wynns                  78.7                0.76
# 80  2022      Tres Barrera                  76.7                0.75
# 81  2022      Mitch Garver                  81.0                0.81
# 82  2022          Sam Huff                  88.1                0.83
# 83  2022        René Pinto                  83.4                0.72
#
#     time_second_base  time_third_base
# 0           2.062565         1.461645
# 1           1.975447         1.399909
# ...

# %%
# Checking for null values
data2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  74 non-null     int64
#  1   catcher               73 non-null     object
#  2   maxeff_arm_2b_3b_sba  74 non-null     float64
#  3   exchange_2b_3b_sba    74 non-null     float64
#  4   time_second_base      74 non-null     float64
#  5   time_third_base       74 non-null     float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 3.6+ KB

# %%
# Dropping null catchers in 2015
data2015 = data2015.dropna(subset=['catcher'])

# %%
# Checking for null values
data2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  80 non-null     int64
#  1   catcher               79 non-null     object
#  2   maxeff_arm_2b_3b_sba  80 non-null     float64
#  3   exchange_2b_3b_sba    80 non-null     float64
#  4   time_second_base      80 non-null     float64
#  5   time_third_base       80 non-null     float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 3.9+ KB

# %%
# Dropping null catchers in 2016
data2016 = data2016.dropna(subset=['catcher'])

# %%
# Checking for null values
data2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  72 non-null     int64
#  1   catcher               72 non-null     object
#  2   maxeff_arm_2b_3b_sba  72 non-null     float64
#  3   exchange_2b_3b_sba    72 non-null     float64
#  4   time_second_base      72 non-null     float64
#  5   time_third_base       72 non-null     float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 3.5+ KB

# %%
# Checking for null values
data2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  85 non-null     int64
#  1   catcher               85 non-null     object
#  2   maxeff_arm_2b_3b_sba  85 non-null     float64
#  3   exchange_2b_3b_sba    85 non-null     float64
#  4   time_second_base      85 non-null     float64
#  5   time_third_base       85 non-null     float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 4.1+ KB

# %%
# Checking for null values
data2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  78 non-null     int64
#  1   catcher               78 non-null     object
#  2   maxeff_arm_2b_3b_sba  78 non-null     float64
#  3   exchange_2b_3b_sba    78 non-null     float64
#  4   time_second_base      78 non-null     float64
#  5   time_third_base       78 non-null     float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 3.8+ KB

# %%
# Checking for null values
data2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  53 non-null     int64
#  1   catcher               53 non-null     object
#  2   maxeff_arm_2b_3b_sba  53 non-null     float64
#  3   exchange_2b_3b_sba    53 non-null     float64
#  4   time_second_base      53 non-null     float64
#  5   time_third_base       53 non-null     float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 2.6+ KB

# %%
# Checking for null values
data2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  82 non-null     int64
#  1   catcher               81 non-null     object
#  2   maxeff_arm_2b_3b_sba  82 non-null     float64
#  3   exchange_2b_3b_sba    82 non-null     float64
#  4   time_second_base      82 non-null     float64
#  5   time_third_base       82 non-null     float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 4.0+ KB

# %%
# Dropping null catchers in 2021
data2021 = data2021.dropna(subset=['catcher'])

# %%
# Checking for null values
data2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  84 non-null     int64
#  1   catcher               84 non-null     object
#  2   maxeff_arm_2b_3b_sba  84 non-null     float64
#  3   exchange_2b_3b_sba    84 non-null     float64
#  4   time_second_base      84 non-null     float64
#  5   time_third_base       84 non-null     float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 4.1+ KB

# %%
# Merging tables into the column year
frames = [data2022, data2021, data2020, data2019, data2018, data2017, data2016, data2015]

result = pd.concat(frames)

# %%
# Final table cleaned
result
# Out:
#     year           catcher  maxeff_arm_2b_3b_sba  exchange_2b_3b_sba  \
# 0   2022       Matt Thaiss                  83.9                0.79
# 1   2022     J.T. Realmuto                  87.6                0.67
# 2   2022        Elias Díaz                  84.8                0.72
# 3   2022        Will Smith                  83.6                0.71
# 4   2022  Chuckie Robinson                  86.3                0.73
# ..   ...               ...                   ...                 ...
# 69  2015       Brayan Peña                  80.1                0.81
# 70  2015     Tyler Flowers                  77.7                0.78
# 71  2015    Jordan Pacheco                  75.7                0.75
# 72  2015     Chris Gimenez                  78.8                0.80
# 73  2015    Kyle Schwarber                  81.4                0.76
#
#     time_second_base  time_third_base
# 0           2.062565         1.461645
# 1           1.975447         1.399909
# ...
